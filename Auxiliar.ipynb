# %%
# Pega a posição do mouse na hora de selecionar a pasta exportar do link
import pyautogui
import time

# Espera 5 segundos para o usuário posicionar o mouse
time.sleep(5)
# Obtém a posição atual do mouse
print(pyautogui.position())
# Out:
# Point(x=83, y=215)
